# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

credentials = ServiceAccountCredentials.from_json_keyfile_name('spreadsheet-api-e754b793bcea.json', scope)
gc = gspread.authorize(credentials)

# ドメイン一覧のスプレッドシートにアクセス
wks = gc.open('ドメイン一覧').sheet1

for cell in wks.range('A1:Z1'):
    if cell.value == "ドメイン名":
        domain_col = cell.col

    if cell.value == "アドマネ移行\n（FTP禁止）":
        admvs_col = cell.col
    
print("domain_col : {}, admvs_col : {}".format(domain_col, admvs_col))

domain_list = wks.col_values(domain_col)[1:]
admvs_list = wks.col_values(admvs_col)[1:]
# Out:
# domain_col : 7, admvs_col : 5

# %%
print("domain number : {}".format(len(domain_list)))
# print(domain_list)
# print(admvs_list)

finished_num = admvs_list.count('×') + admvs_list.count('済')
print("finished : {}".format(finished_num))

client_not_found_num = admvs_list.count("アドマネにクライアント名無し")
domain_not_found_num = admvs_list.count("存在しないドメイン、パス・もしくは複数ドメインが存在している")
staff_client_not_found_num = admvs_list.count("担当者・クライアント不明")


not_finished_num = admvs_list.count("")
# Out:
# domain number : 442
# ['×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', '×', 'アドマネにクライアント名無し', 'アドマネにクライアント名無し', 'アドマネにクライアント名無し', 'アドマネにクライアント名無し', 'アドマネにクライアント名無し', 'アドマネにクライアント名無し', 'アドマネにクライアント名無し', 'アドマネにクライアント名無し', 'アドマネにクライアント名無し', 'アドマネにクライアント名無し', 'アドマネにクライアント名無し', 'アドマネに担当者登録なし', 'クライアントリストに会社名なし', 'クライアントリストに会社名なし', 'クライアント不明', '移行処理の途中です(Server Error 500)', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '済', '存在しないドメイン、パス・もしくは複数ドメインが存在している', '存在しないドメイン、パス・もしくは複数ドメインが存在している', '存在しないドメイン、パス・もしくは複数ドメインが存在している', '存在しないドメイン、パス・もしくは複数ドメインが存在している', '存在しないドメイン、パス・もしくは複数ドメインが存在している', '済', '済', '済', '存在しないドメイン、パス・もしくは複数ドメインが存在している', '済', '存在しないドメイン、パス・もしくは複数ドメインが存在している', '存在しないドメイン、パス・もしくは複数ドメインが存在している', '存在しないドメイン、パス・もしくは複数ドメインが存在している', '存在しないドメイン、パス・もしくは複数ドメインが存在している', '存在しないドメイン、パス・もしくは複数ドメインが存在している', '存在しないドメイン、パス・もしくは複数ドメインが存在している', '存在しないドメイン、パス・もしくは複数ドメインが存在している', '済', '存在しないドメイン、パス・もしくは複数ドメインが存在している', '存在しないドメイン、パス・もしくは複数ドメインが存在している', '存在しないドメイン、パス・もしくは複数ドメインが存在している', '済', '存在しないドメイン、パス・もしくは複数ドメインが存在している', '存在しないドメイン、パス・もしくは複数ドメインが存在している', '担当者・クライアント不明', '担当者・クライアント不明', '担当者・クライアント不明', '担当者・クライアント不明', '担当者・クライアント不明', '担当者・クライアント不明', '担当者・クライアント不明', '担当者・クライアント不明', '担当者・クライアント不明', '担当者・クライアント不明', '担当者・クライアント不明', '担当者・クライアント不明', '担当者・クライアント不明', '担当者・クライアント不明', '担当者・クライアント不明', '担当者・クライアント不明', '担当者・クライアント不明', '担当者・クライアント不明', '担当者・クライアント不明', '担当者・クライアント不明', '担当者不明', '担当者不明', '担当者不明', '担当者不明', '担当者不明', '担当者不明', '担当者不明', '', '', '済', '', '', '', '', '済', '', '', '', '', '', '', '', '', '済', '済', '済', '済', '済', '済', '誤登録', '誤登録', '済', '済', '済', '済', '済', '済', '', '済', '済', '済', '済', '済', '済', '済', '済', '済', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '済', '済', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '済', '済']
# finished : 257

# %%
# テスト用に作成した spread sheet 上でいろいろテスト

wks2 = gc.open("test_spread_sheet_api").sheet1

wks2.update_cell(1, 3, "goodbye world")

wks2.row_values(1)
# Out:
# ['hello world', '', 'goodbye world']
