# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data/curve_fitting.csv", header=None).values

plt.scatter(data[:, 0], data[:, 1], );

ground_truth = np.array([[x, math.exp(0.3 * x + 0.1)] for x in np.arange(0, 10, 0.1)])
plt.plot(ground_truth[:, 0], ground_truth[:, 1], color="red")

plt.show()
